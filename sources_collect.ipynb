# %%
import arxiv

# Construire une requête
search = arxiv.Search(
  query = "machine learning",
  max_results = 5,
  sort_by = arxiv.SortCriterion.SubmittedDate
)

# Itérer sur les résultats
for result in search.results():
  print(result.title)
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_1360\1423007986.py:11: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for result in search.results():
# DInf-Grid: A Neural Differential Equation Solver with Differentiable Feature Grids
# MatchTIR: Fine-Grained Supervision for Tool-Integrated Reasoning via Bipartite Matching
# High-accuracy and dimension-free sampling with diffusions
# See Less, Drive Better: Generalizable End-to-End Autonomous Driving via Foundation Models Stochastic Patch Selection
# Distributed Perceptron under Bounded Staleness, Partial Participation, and Noisy Communication

# %%
import arxiv

search = arxiv.Search(
    query="embedding",
    max_results=5,
    sort_by=arxiv.SortCriterion.SubmittedDate
)

for paper in search.results():
    print(f"Titre : {paper.title}")
    print(f"Auteurs : {paper.authors}")
    print(f"Résumé : {paper.summary[:200]}...")
    print(f"Lien : {paper.pdf_url}\n")
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_21672\2584291130.py:9: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for paper in search.results():
# Titre : Spectral Appearance of Self-gravitating AGN Disks Powered by Stellar Objects: Universal Effective Temperature in the Optical Continuum and Application to Little Red Dots
# Auteurs : [arxiv.Result.Author('Yi-Xian Chen'), arxiv.Result.Author('Hanpu Liu'), arxiv.Result.Author('Ruancun Li'), arxiv.Result.Author('Bingjie Wang'), arxiv.Result.Author('Yilun Ma'), arxiv.Result.Author('Yan-Fei Jiang'), arxiv.Result.Author('Jenny Greene'), arxiv.Result.Author('Eliot Quataert'), arxiv.Result.Author('Jeremy Goodman')]
# Résumé : We revisit the spectral appearance of extended self-gravitating accretion disks around supermassive black holes. Using dust-poor opacity tables, we show that all optically thick disk solutions possess...
# Lien : https://arxiv.org/pdf/2602.06954v1
#
# Titre : Reciprocal Latent Fields for Precomputed Sound Propagation
# Auteurs : [arxiv.Result.Author('Hugo Seuté'), arxiv.Result.Author('Pranai Vasudev'), arxiv.Result.Author('Etienne Richan'), arxiv.Result.Author('Louis-Xavier Buffoni')]
# Résumé : Realistic sound propagation is essential for immersion in a virtual scene, yet physically accurate wave-based simulations remain computationally prohibitive for real-time applications. Wave coding met...
# Lien : https://arxiv.org/pdf/2602.06937v1
#
# Titre : Directing Space: Rehearsing Architecture as Performer with Explainable AI
# Auteurs : [arxiv.Result.Author('Pavlos Panagiotidis'), arxiv.Result.Author('Jocelyn Spence'), arxiv.Result.Author('Nils Jaeger'), arxiv.Result.Author('Paul Tennent')]
# Résumé : As AI systems increasingly become embedded in interactive and im-mersive artistic environments, artists and technologists are discovering new opportunities to engage with their interpretive and autono...
# Lien : https://arxiv.org/pdf/2602.06915v1
#
# Titre : Symmetry and localisation in causally constrained quantum operator dynamics
# Auteurs : [arxiv.Result.Author('Marcell D. Kovács'), arxiv.Result.Author('Christopher J. Turner'), arxiv.Result.Author('Lluís Masanes')]
# Résumé : This paper explores the connection between causality and many-body dynamics by studying the algebraic structure of tri-partite unitaries ('walls') which permanently arrest local operator spreading in ...
# Lien : https://arxiv.org/pdf/2602.06913v1
#
# Titre : Zero-shot Generalizable Graph Anomaly Detection with Mixture of Riemannian Experts
# Auteurs : [arxiv.Result.Author('Xinyu Zhao'), arxiv.Result.Author('Qingyun Sun'), arxiv.Result.Author('Jiayi Luo'), arxiv.Result.Author('Xingcheng Fu'), arxiv.Result.Author('Jianxin Li')]
# Résumé : Graph Anomaly Detection (GAD) aims to identify irregular patterns in graph data, and recent works have explored zero-shot generalist GAD to enable generalization to unseen graph datasets. However, exi...
# Lien : https://arxiv.org/pdf/2602.06859v1
